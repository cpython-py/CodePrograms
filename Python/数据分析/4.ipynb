# %%
import pandas as pd
# data = pd.read_csv('./4.csv')
# print(data)
# print(type(data))
data = pd.read_csv('./4.csv',index_col='order_id')
print(data)
# Out:
#           id   user_id  payment  price
# order_id
# 3515712    1  34982388     6200   6200
# 3515713    2  17463833     7000   7000
# 3515714    3  70145358    10000  10000
# 3515715    4  46519215     8500   8500
