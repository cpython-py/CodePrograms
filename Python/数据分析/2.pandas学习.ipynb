# %%
import pandas as pd

# %%
# 创建Series数组
s = pd.Series([1, 2, 3, 4, 5])
print(s)
# 自定义索引
s = pd.Series([10, 2, 3, 4, 5], index=['A', 'B', 'C', 'D', 'E'])
print(s)
# 定义name
s = pd.Series([10, 2, 3, 4, 5], index=['A', 'B', 'C', 'D', 'E'], name='月份')
print(s)
# 通过字典来创建
s = pd.Series({'a':1, 'b':2, 'c':3, 'd':4, 'e':5})
print(s)
# 继承
s1 = pd.Series(s, index=['a', 'c'])
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# A    10
# B     2
# C     3
# D     4
# E     5
# dtype: int64
# A    10
# B     2
# C     3
# D     4
# E     5
# Name: 月份, dtype: int64
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a    1
# c    3
# dtype: int64

# %%
# Series的属性
s = pd.Series([10, 2, 3, 4, 5], index=['A', 'B', 'C', 'D', 'E'], name='月份')
print(s.index)
print(s.values)
print(s.ndim, s.shape, s.size, s.dtype, s.name)
print(s.loc['A']) # 显示索引 按标签名 更推荐
print(s.loc['A':'C'])
print(s.iloc[0]) # 隐式索引 按位置 更推荐
print(s.iloc[0:2])
print(s.at['B']) # 显示索引 不支持切片
print(s.iat[4]) # 隐式索引 不支持切片
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')
# [10  2  3  4  5]
# 1 (5,) 5 int64 月份
# 10
# A    10
# B     2
# C     3
# Name: 月份, dtype: int64
# 10
# A    10
# B     2
# Name: 月份, dtype: int64
# 2
# 5

# %%
# 访问数据
s = pd.Series([1, 2, 3, 4, 5], index=['A', 'B', 'C', 'D', 'E'], name='月份')
s['F'] = 6
print(s)
print(s['A'])
print(s[s<3])
print(s.head()) # * 默认获取表格中前5行的信息 可以在括号内写入数字, 如写入3, 会获取前3行的数据
print(s.tail()) # * 默认获取表格中后5行的信息 可以在括号内写入数字, 如写入2, 会获取后2行的数据
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# F    6
# Name: 月份, dtype: int64
# 1
# A    1
# B    2
# Name: 月份, dtype: int64
# A    1
# B    2
# C    3
# D    4
# E    5
# Name: 月份, dtype: int64
# B    2
# C    3
# D    4
# E    5
# F    6
# Name: 月份, dtype: int64

# %%
# Series常见函数
import numpy as np
s = pd.Series([10, 2, np.nan, None, 3, 4, 5], index=['A', 'B', 'C', 'D', 'E', 'F', 'G'])
print(s)
print(s.head())
print(s.describe()) # * 获取所有描述性信息 count 会忽略缺失值NaN
print(s.count())
print(s.keys()) # * 获取索引对象
print(s.index) # * 和keys()效果相同
print(s.isna()) # * 判断某个元素是否为缺失值
print(s.isin([4])) # * 判断某个元素是否存在 需要传入列表
print(s.mean(), s.std(), s.var(), s.min(), s.max(), s.sum())
print(s.median())
print(s.sort_values()) # * 按值排序
print(s.sort_index()) # * 按索引排序
print(s.quantile(0.25)) # * 传入的数字为 [0, 1]
s['H'] = 2
print(s.mode()) # * 众数
print(s.value_counts()) # * 值出现的次数 忽略缺失值
print(s.drop_duplicates(), type(s.drop_duplicates())) # * 去重 缺失值会变成1个
print(s.unique(), type(s.unique())) # * 去重 返回的数据类型和drop_duplicates()不一样, 返回numpy的ndarray类型
print(s.nunique()) # * 返回去重后的个数
# Out:
# A    10.0
# B     2.0
# C     NaN
# D     NaN
# E     3.0
# F     4.0
# G     5.0
# dtype: float64
# A    10.0
# B     2.0
# C     NaN
# D     NaN
# E     3.0
# dtype: float64
# count     5.000000
# mean      4.800000
# std       3.114482
# min       2.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max      10.000000
# dtype: float64
# 5
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G'], dtype='object')
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G'], dtype='object')
# A    False
# B    False
# C     True
# D     True
# E    False
# F    False
# G    False
# dtype: bool
# A    False
# B    False
# C    False
# D    False
# E    False
# F     True
# G    False
# dtype: bool
# 4.8 3.1144823004794877 9.700000000000001 2.0 10.0 24.0
# 4.0
# B     2.0
# E     3.0
# F     4.0
# G     5.0
# A    10.0
# C     NaN
# D     NaN
# dtype: float64
# A    10.0
# B     2.0
# C     NaN
# D     NaN
# E     3.0
# F     4.0
# G     5.0
# dtype: float64
# 3.0
# 0    2.0
# dtype: float64
# ...

# %%
# 案例.学生成绩统计
np.random.seed(42)
scores = pd.Series(np.random.randint(50, 101, 10), index=['Student'+str(i) for i in range(1, 11)])
print(scores)
print(scores.mean()) # 平均分
print(scores.max()) # 最高分
print(scores.min()) # 最低分
print(scores[scores>scores.mean()].size) # 高于平均分的人数
# Out:
# Student1     88
# Student2     78
# Student3     64
# Student4     92
# Student5     57
# Student6     70
# Student7     88
# Student8     68
# Student9     72
# Student10    60
# dtype: int32
# 73.7
# 92
# 57
# 4

# %%
# 案例.温度数据分析
temperatures = pd.Series([28, 31, 29, 32, 30, 27, 33], index=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
print(temperatures[temperatures>30].size) # 温度大于30的天数
print(temperatures.mean()) # 平均温度
print(temperatures.sort_values(ascending=False)) # 按温度从高到低排序 # ? ascending是否升序, 不影响原始数组
print(*temperatures.diff().abs().sort_values(ascending=False).keys()[:2].tolist()) # 获取温度变化最大的两天 # ? 1=>diff() 获取相邻两个元素的后-前的差值 2=>tolist()转换成列表 3=> * 去掉列表的中括号

# %%
# 案例.股票价格分析
prices = pd.Series([102.3, 103.5, 105.1, 104.8, 106.2, 107.0, 106.5, 108.1, 109.3, 110.2], index=pd.date_range('2026-04-10', periods=10))
# ? pandas.date_range() 日期序列, periods 序列长度
print(prices)
print(prices.pct_change()) # 计算每日收益率, # ?收益率 = (今天的/昨天的) -1
print(prices.pct_change().idxmax(), prices.pct_change().idxmin(), sep='\t|\t') # 收益率最高和最低的日期 # * 1.idx- 获取对应的索引
print(prices.std()) # 波动率
# Out:
# 2026-04-10    102.3
# 2026-04-11    103.5
# 2026-04-12    105.1
# 2026-04-13    104.8
# 2026-04-14    106.2
# 2026-04-15    107.0
# 2026-04-16    106.5
# 2026-04-17    108.1
# 2026-04-18    109.3
# 2026-04-19    110.2
# Freq: D, dtype: float64
# 2026-04-10         NaN
# 2026-04-11    0.011730
# 2026-04-12    0.015459
# 2026-04-13   -0.002854
# 2026-04-14    0.013359
# 2026-04-15    0.007533
# 2026-04-16   -0.004673
# 2026-04-17    0.015023
# 2026-04-18    0.011101
# 2026-04-19    0.008234
# Freq: D, dtype: float64
# 2026-04-12 00:00:00	|	2026-04-16 00:00:00
# 2.483724801359622

# %%
# 案例.销售数据分析
sales = pd.Series([120, 135, 145, 160, 155, 170, 180, 175, 190, 200, 210, 220], index=pd.date_range('2026-04-10', periods=12, freq='MS'))
print(sales)
print(sales.resample('QS').mean()) # 季度的平均销量 # * resample() 重新采样 'QS' 按每个季度
print(sales.resample('QS').mean().idxmax()) # 平均销量最高的季度
print(sales.pct_change()) # 月环比的增长率
Gt0 = sales.pct_change() > 0
print(Gt0[Gt0.rolling(3).sum()==3].keys().tolist()) # 找出连续增长超过两个月的月份
# Out:
# 2026-05-01    120
# 2026-06-01    135
# 2026-07-01    145
# 2026-08-01    160
# 2026-09-01    155
# 2026-10-01    170
# 2026-11-01    180
# 2026-12-01    175
# 2027-01-01    190
# 2027-02-01    200
# 2027-03-01    210
# 2027-04-01    220
# Freq: MS, dtype: int64
# 2026-04-01    127.500000
# 2026-07-01    153.333333
# 2026-10-01    175.000000
# 2027-01-01    200.000000
# 2027-04-01    220.000000
# Freq: QS-JAN, dtype: float64
# 2027-04-01 00:00:00
# 2026-05-01         NaN
# 2026-06-01    0.125000
# 2026-07-01    0.074074
# 2026-08-01    0.103448
# 2026-09-01   -0.031250
# 2026-10-01    0.096774
# 2026-11-01    0.058824
# 2026-12-01   -0.027778
# 2027-01-01    0.085714
# 2027-02-01    0.052632
# 2027-03-01    0.050000
# 2027-04-01    0.047619
# Freq: MS, dtype: float64
# [Timestamp('2026-08-01 00:00:00'), Timestamp('2027-03-01 00:00:00'), Timestamp('2027-04-01 00:00:00')]

# %%
# 案例.每小时销售数据分析
np.random.seed(42)
hours_sales = pd.Series(np.random.randint(0, 100, 24), index=pd.date_range('2026-4-10', periods=24, freq='h'))
day_sales = hours_sales.resample('D').sum()
print(day_sales) # 计算每日总销售额
business_hours_sales = hours_sales[(hours_sales.index.hour>=8) & (hours_sales.index.hour<=22)].sum()
print('-----' * 10)
print(business_hours_sales / (day_sales - business_hours_sales)) # 计算营业时间和非营业时间的销售额比例
print(*hours_sales.nlargest(3).keys().tolist(), sep='\n') # 找出销售额最高的三个小时
# Out:
# 2026-04-10    1205
# Freq: D, dtype: int32
# --------------------------------------------------
# 2026-04-10    1.429435
# Freq: D, dtype: float64
# 2026-04-10 11:00:00
# 2026-04-10 01:00:00
# 2026-04-10 10:00:00
