# %%
import numpy as np
import pandas as pd
# TODO 创建一个DataFrame数据类型的对象
data = {'rank':[1,2,3,4],'GDP':[80855,77388,68024,47252]}
city = ['GD','JS','SD','ZJ']
df = pd.DataFrame(data,index=city)
print(df)

# %%
# TODO columns自定义列表索引
data = [['May',689],['Tony',659],['kevin',635]]
rank = [1,2,3]
result = pd.DataFrame(data,index=rank,columns=['name','score'])
print(result)
print(type(result))
print(result.dtypes)
print(result.values)
print(result.index)
# Out:
#     name  score
# 1    May    689
# 2   Tony    659
# 3  kevin    635
# <class 'pandas.core.frame.DataFrame'>
# name     object
# score     int64
# dtype: object
# [['May' 689]
#  ['Tony' 659]
#  ['kevin' 635]]
# Int64Index([1, 2, 3], dtype='int64')
