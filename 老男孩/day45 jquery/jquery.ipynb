# %%
import requests

# url = "https://cdn.bootcdn.net/ajax/libs/jquery/3.7.1/jquery.js"
# response = requests.get(url)
# print(response.text)

url = "https://cdn.bootcdn.net/ajax/libs/twitter-bootstrap/5.3.8/css/bootstrap-grid.css"
response = requests.get(url)
print(response.text)

# %%
import requests
url = "https://cdn.bootcdn.net/ajax/libs/jquery/3.7.1/jquery.js"
response = requests.get(url)
print(response.text)
