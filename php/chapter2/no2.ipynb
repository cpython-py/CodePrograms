# %% [markdown]
# ## 局部和全局作用域
# 在所有函数外部定义的变量拥有全局作用域.除了函数外,全局变量可以被脚本中的任何部分访问,要在一个函数访问全局变量,需要global关键字
# 在php函数内部声明的变量是全局变量,反能在函数内部访问:

# %%
a = 10
print(a)
a = 15
# Out:
# 10

# %%
print(a)
# Out:
# 15
